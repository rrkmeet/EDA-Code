# %%
#Line Charts
import matplotlib.pyplot as plt
import seaborn as sns

# %%
yield_apples=[0.895,0.91,0.919,0.926,0.929,0.931]

# %%
plt.plot(yield_apples)

# %%
sales=[5000,1000,15000,2000,50000,1000,4500]
plt.plot(sales)

# %%
years=[2010,2012,2013,2014,2015,2016]
sales=[15000,40000,1500,25000,35000,12000]
plt.plot(years,sales)
plt.xlabel('Year')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
years=range(2018,2024)
apple_sales=[15000,40000,1500,25000,35000,12000]
orange_sales=[5000,20000,11500,35000,75000,2000]
plt.plot(years,apple_sales)
plt.plot(years,orange_sales)
plt.xlabel('Year')
plt.ylabel('Fruit Sales')
# Out:
# Text(0, 0.5, 'Fruit Sales')

# %%
years=range(2018,2024)
apple_sales=[15000,40000,1500,25000,35000,12000]
orange_sales=[5000,20000,11500,35000,75000,2000]
plt.plot(years,apple_sales)
plt.plot(years,orange_sales)
plt.xlabel('Year')
plt.ylabel('Fruit Sales Range')

plt.title('Fruit Sales Line Chart')
plt.legend(['apple_sales','orange_sales'])

# %%
years=range(2018,2024)
apple_sales=[15000,40000,1500,25000,35000,12000]
orange_sales=[5000,20000,11500,35000,75000,2000]
plt.plot(years,apple_sales,marker='o')
plt.plot(years,orange_sales,marker='x')
plt.xlabel('Year')
plt.ylabel('Fruit Sales Range')

plt.title('Fruit Sales Line Chart')
plt.legend(['apple_sales','orange_sales'])

# %%
plt.figure(figsize=(10,6))
years=range(2018,2024)
apple_sales=[15000,40000,1500,25000,35000,12000]
orange_sales=[5000,20000,11500,35000,75000,2000]
plt.plot(years,apple_sales,marker='o')
plt.plot(years,orange_sales,marker='x')
plt.xlabel('Year')
plt.ylabel('Fruit Sales Range')

plt.title('Fruit Sales Line Chart')
plt.legend(['apple_sales','orange_sales'])

# %%
plt.figure(figsize=(10,6))
years=range(2018,2024)
apple_sales=[15000,40000,1500,25000,35000,12000]
orange_sales=[5000,20000,11500,35000,75000,2000]
plt.plot(years,apple_sales,marker='o')

plt.xlabel('Year')
plt.ylabel('Fruit Sales Range')

plt.title('Fruit Sales Line Chart')
plt.legend(['apple_sales','orange_sales'])

# %%
#Using Seaborn
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
years=range(2018,2024)
apple_sales=[15000,40000,1500,25000,35000,12000]
orange_sales=[5000,20000,11500,35000,75000,2000]
plt.plot(years,apple_sales,marker='o')
plt.plot(years,orange_sales,marker='x')
plt.xlabel('Year')
plt.ylabel('Fruit Sales Range')

plt.title('Fruit Sales Line Chart')
plt.legend(['apple_sales','orange_sales'])

# %%
#Using Seaborn
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
years=range(2018,2024)
apple_sales=[15000,40000,1500,25000,35000,12000]
orange_sales=[5000,20000,11500,35000,75000,2000]
plt.plot(years,apple_sales,marker='o')
plt.plot(years,orange_sales,marker='x')
plt.xlabel('Year')
plt.ylabel('Fruit Sales Range')

plt.title('Fruit Sales Line Chart')
plt.legend(['apple_sales','orange_sales'])

# %%
import pandas as pd                     
import matplotlib.pyplot as plt          # plotting
import numpy as np                       # dense matrices
from scipy.sparse import csr_matrix      # sparse matrices
# %matplotlib inline

df = pd.DataFrame({'year': [2012],
                   'sales_percentage': [0.95,0.22,0.63,0.75,0.85]},
                  index=['apple', 'banana', 'grapes','pomogranate','strawberry'])
plot = df.plot.pie(y='sales_percentage', figsize=(5, 5))

# %%
import matplotlib.pyplot as plt
import pandas as pd
 

# initializing the data
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR',]
data = [23, 13, 35, 15, 12]
 
explode = [0.1, 0.5, 0, 0, 0]
 
colors = ( "orange", "cyan", "yellow",
          "grey", "green",)
 
# plotting the data
plt.pie(data, labels=cars, explode=explode, autopct='%1.2f%%',
        colors=colors, shadow=True)
 
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
years=range(2018,2024)
apple_sales=[15000,40000,1500,25000,35000,12000]
 
# plotting the data
plt.bar(years, apple_sales)
 
# Adding title to the plot
plt.title("Tips Dataset")
 
# Adding label on the y-axis
plt.ylabel('Total Bill')
 
# Adding label on the x-axis
plt.xlabel('Day')
 
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
years=range(2018,2024)
apple_sales=[15000,40000,1500,25000,35000,12000]
 # plotting the data
plt.bar(years, apple_sales)
 # Adding title to the plot
plt.title("Sales Trends")
 # Adding label on the y-axis
plt.ylabel('Sales')
 # Adding label on the x-axis
plt.xlabel('Year')

plt.bar(years, apple_sales,color='yellow', edgecolor='blue', 
        linewidth=1)
plt.show()

# %%
#Histogram
import matplotlib.pyplot as plt
import pandas as pd

years=range(2018,2026)
apple_sales=[15000,40000,1500,25000,35000,12000,52000,48000]
 # plotting the data

 # Adding title to the plot
plt.title("Sales Trends")
 # Adding label on the y-axis
plt.ylabel('Sales')
 # Adding label on the x-axis
plt.xlabel('Year')

plt.hist(apple_sales,)
plt.show()

# %%
#scatterplot
years=range(2018,2038)
apple_sales=[251000,44000,89000,6300,796589,155000,5000,2000,15000,18000,96000,255000,100000,40000,155600,225000,35000,12000,2000,16000]
plt.title("Scatterplot")
 
# Adding label on the y-axis
plt.ylabel('Sales')
 
# Adding label on the x-axis
plt.xlabel('Year')
sns.scatterplot(x=years,y=apple_sales,color='red')
# Out:
# <Axes: title={'center': 'Scatterplot'}, xlabel='Year', ylabel='Sales'>

# %%
#save
import matplotlib.pyplot as plt
 
# Creating data
year = ['2010', '2002', '2004', '2006', '2008']
production = [25, 15, 35, 30, 10]
 
# Plotting barchart
plt.bar(year, production)
 
# Saving the figure.
plt.savefig("output.jpg")
 
# Saving figure by changing parameter values
plt.savefig("output1", facecolor='y', bbox_inches="tight",
            pad_inches=0.3, transparent=True)
